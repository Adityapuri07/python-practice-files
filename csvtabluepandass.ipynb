# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\win10\Downloads\health care diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data['Age_new'] =

# %%
data['Age']<25
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767     True
# Name: Age, Length: 768, dtype: bool

# %%
age = []
for i  in data['Age']:
    if i>=20 and i<=25:
        age.append('20-25')
    elif i>=25 and i<=30:
         age.append('25-30')
    elif i>=30 and i<=35:
         age.append('30-35') 
    elif i>=35 and i<=40:
         age.append('35-40')        
    elif i>=40 and i<=45:
         age.append('40-45')
    elif i>=45 and i<=50:
         age.append('45-50')             
    elif i>=50 and i<=55:
         age.append('50-55') 
    elif i>=55 and i<=60:
         age.append('55-60') 
    elif i>=60 and i<=65:
         age.append('60-65')
    elif i>=65 and i<=70:
         age.append('65-70')  
    elif i>=70 and i<=75:
         age.append('70-75') 
    elif i>=75 and i<=80:
         age.append('75-80')  
    elif i>=80 and i<=85:
         age.append('80-85')

# %%
print(age)
# Out:
# ['45-50', '30-35', '30-35', '20-25', '30-35', '25-30', '25-30', '25-30', '50-55', '50-55', '25-30', '30-35', '55-60', '55-60', '50-55', '30-35', '30-35', '30-35', '30-35', '30-35', '25-30', '45-50', '40-45', '25-30', '50-55', '40-45', '40-45', '20-25', '55-60', '35-40', '55-60', '25-30', '20-25', '25-30', '40-45', '30-35', '30-35', '45-50', '25-30', '55-60', '25-30', '35-40', '45-50', '50-55', '35-40', '20-25', '25-30', '20-25', '30-35', '20-25', '20-25', '25-30', '25-30', '55-60', '40-45', '20-25', '40-45', '30-35', '40-45', '20-25', '20-25', '35-40', '35-40', '20-25', '40-45', '30-35', '35-40', '50-55', '20-25', '25-30', '25-30', '25-30', '40-45', '20-25', '20-25', '20-25', '40-45', '25-30', '25-30', '20-25', '20-25', '20-25', '35-40', '20-25', '35-40', '25-30', '40-45', '25-30', '40-45', '20-25', '20-25', '30-35', '40-45', '55-60', '20-25', '35-40', '20-25', '20-25', '20-25', '30-35', '30-35', '20-25', '20-25', '20-25', '25-30', '20-25', '25-30', '35-40', '20-25', '20-25', '20-25'
# ...

# %%
data['Age_new']=age 
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome Age_new
# 0                       0.627   50        1   45-50
# ...

# %%
data.to_csv("new_dataset.csv")

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\win10\Downloads\health care diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
result=[]
for i in data ['Outcome']:
    if i == 1:
        result.append("diabetic")
    else:
        result.append("non_diabetic")

# %%
data['diabetic or non_diabetic']=result
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome Age_new diabetic or non_diabetic
# ...

# %%
data.to_csv('allinone_dataset.csv')
